# %% [markdown]
# <a href="https://colab.research.google.com/github/aliza1800/flyrank-ml-internship/blob/main/work/notebooks/ml-02_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aliza1800/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **My lane: Refresh / Content Opportunity Scoring**
#
# I chose the Refresh / Content Opportunity Scoring lane because I want to identify which content pages should be reviewed first for improvement. This lane connects observable search and engagement signals with a practical content decision. I will use the available data to find pages that show meaningful visibility along with signs of weakness or opportunity. The result will be used as decision-support for human review, not as a guarantee that a page will improve.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision I want to improve is which content pages should be reviewed first for refresh or improvement. A content or SEO reviewer would use the ranked recommendations to decide where to spend limited review time. A wrong recommendation could waste review effort on a low-value page, while missing an important page could delay a useful content improvement. Therefore, the goal is to prioritize pages using observable evidence rather than guarantee that an action will improve performance.

# %%
print("Decision: prioritize content pages for human review.")
print("Primary user: content/SEO reviewer.")
# Out:
# Decision: prioritize content pages for human review.
# Primary user: content/SEO reviewer.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# I will inspect the starter dataset to understand its size and the amount of search and engagement evidence available. I will use the observed data to determine whether there is enough signal to justify building a content review prioritization model.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/content_refresh_anonymized.csv")

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))
print("Pages with impressions:", (df["impressions_90d"] > 0).sum())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_721/3843769597.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../data/raw/content_refresh_anonymized.csv")
#       4
#       5 print("Number of rows:", len(df))
#
# ...

# %% [markdown]
# These initial checks show that the starter dataset contains enough content pages and observable search evidence to continue with baseline scoring and model development.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work will use observed and measured search and engagement signals to identify pages that may deserve review. The results will provide directional insights and decision-support for prioritizing content review. I can compare different approaches and evaluate whether my ranking performs better than a simple baseline on the available data.
#
# I cannot claim that a refresh will definitely improve a page, that my analysis proves a causal relationship, or that I can predict Google's ranking algorithm. The results will be based on the available anonymized data and should be interpreted as evidence for human review, not as guaranteed outcomes.

# %%
print("Claims supported: observed, measured, directional, decision-support.")
print("Claims not supported: causal proof or predicting Google's algorithm.")

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
